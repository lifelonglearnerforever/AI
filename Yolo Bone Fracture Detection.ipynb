# %%
# !pip install ultralytics
from ultralytics import YOLO
from PIL import Image

# %%
TEST_PATH = "/kaggle/input/bone-fracture-detection-computer-vision-project/BoneFractureYolo8/test"
TRAIN_PATH = "/kaggle/input/bone-fracture-detection-computer-vision-project/BoneFractureYolo8/train"
VALID_PATH = "/kaggle/input/bone-fracture-detection-computer-vision-project/BoneFractureYolo8/valid"
DATA_YAML = "/kaggle/input/bone-fracture-detection-computer-vision-project/BoneFractureYolo8/data.yaml"

# %%
! ls /kaggle/input/yolov8x.pt/other/default/1
# Out:
# yolov8x.pt

# %%
# Load a model
model = YOLO("/kaggle/input/yolov8x.pt/other/default/1/yolov8x.pt")  # build a new model from scratch

# %%
model.train(data=DATA_YAML, epochs=50, imgsz=256, batch=10)
# Out:
# Ultralytics YOLOv8.2.70 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
metrics = model.val()
print(metrics.box.map)
# Out:
# Ultralytics YOLOv8.2.70 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 268 layers, 68,130,309 parameters, 0 gradients, 257.4 GFLOPs
# val: Scanning /kaggle/input/bone-fracture-detection-computer-vision-project/BoneFractureYolo8/valid/labels... 348 images, 175 backgrounds, 0 corrupt: 100%|██████████| 348/348 [00:00<00:00, 667.70it/s]
# val: WARNING ⚠️ Cache directory /kaggle/input/bone-fracture-detection-computer-vision-project/BoneFractureYolo8/valid is not writeable, cache not saved.
# /opt/conda/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 35/35 [00:05<00:00,  6.52it/s]
#                    all        348        204      0.305      0.249      0.208     0.0756
# ...

# %%
ls -a /kaggle/working/runs/detect/train3/weights/
# Out:
# ./  ../  best.pt  last.pt

# %%
path = !yolo export model=/kaggle/working/runs/detect/train3/weights/best.pt format=onnx

# %%
path
# Out:
# ['Ultralytics YOLOv8.2.70 🚀 Python-3.10.13 torch-2.1.2 CPU (Intel Xeon 2.00GHz)',
#  'Model summary (fused): 268 layers, 68,130,309 parameters, 0 gradients, 257.4 GFLOPs',
#  '',
#  "\x1b\x1bPyTorch:\x1b starting from '/kaggle/working/runs/detect/train3/weights/best.pt' with input shape (1, 3, 256, 256) BCHW and output shape(s) (1, 11, 1344) (130.3 MB)",
#  '',
#  '\x1b\x1bONNX:\x1b starting export with onnx 1.16.1 opset 17...',
#  "\x1b\x1bONNX:\x1b export success ✅ 4.3s, saved as '/kaggle/working/runs/detect/train3/weights/best.onnx' (260.0 MB)",
#  '',
#  'Export complete (8.2s)',
#  'Results saved to \x1b/kaggle/working/runs/detect/train3/weights\x1b',
#  'Predict:         yolo predict task=detect model=/kaggle/working/runs/detect/train3/weights/best.onnx imgsz=256  ',
#  'Validate:        yolo val task=detect model=/kaggle/working/runs/detect/train3/weights/best.onnx imgsz=256 data=/kaggle/input/bone-fracture-detection-computer-vision-project/BoneFractureYolo8/data.yaml  ',
# ...

# %%
import glob
modelTest = YOLO('/kaggle/working/runs/detect/train3/weights/best.pt')
testImages = glob.glob("/kaggle/input/bone-fracture-detection-computer-vision-project/BoneFractureYolo8/test/images/*.jpg")
out = modelTest(test_image)
# Out:
# 0: 256x256 (no detections), 10.1ms
# 1: 256x256 (no detections), 10.1ms
# 2: 256x256 (no detections), 10.1ms
# 3: 256x256 (no detections), 10.1ms
# 4: 256x256 (no detections), 10.1ms
# 5: 256x256 (no detections), 10.1ms
# 6: 256x256 1 forearm fracture, 10.1ms
# 7: 256x256 1 humerus, 10.1ms
# 8: 256x256 (no detections), 10.1ms
# 9: 256x256 (no detections), 10.1ms
# 10: 256x256 1 forearm fracture, 10.1ms
# 11: 256x256 (no detections), 10.1ms
# 12: 256x256 (no detections), 10.1ms
# 13: 256x256 (no detections), 10.1ms
# 14: 256x256 (no detections), 10.1ms
# 15: 256x256 (no detections), 10.1ms
# 16: 256x256 (no detections), 10.1ms
# 17: 256x256 (no detections), 10.1ms
# 18: 256x256 (no detections), 10.1ms
# 19: 256x256 (no detections), 10.1ms
# 20: 256x256 (no detections), 10.1ms
# 21: 256x256 (no detections), 10.1ms
# 22: 256x256 (no detections), 10.1ms
# 23: 256x256 (no detections), 10.1ms
# 24: 256x256 (no detections), 10.1ms
# 25: 256x256 1 shoulder fracture, 10.1ms
# ...
